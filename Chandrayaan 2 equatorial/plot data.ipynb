# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("690days_near_equatorial.csv", header=0)

# %%
display(df)
df.plot(subplots= True, figsize= (10,10))
# Out:
#          chandrayaan.Luna.Altitude  chandrayaan.ElapsedDays  \
# 0                       117.607752                 0.000000
# 1                       117.616119                 0.000428
# 2                       117.627844                 0.000850
# 3                       117.642869                 0.001267
# 4                       117.661525                 0.001689
# ...                            ...                      ...
# 1371063                  90.776952               689.998559
# 1371064                  91.711311               689.999004
# 1371065                  92.599450               689.999413
# 1371066                  93.440817               689.999790
# 1371067                  93.920996               690.000000
#
#          chandrayaan.Luna.ECC  chandrayaan.Luna.SMA  \
# 0                    0.002044           1859.300000
# 1                    0.002029           1859.271523
# 2                    0.002015           1859.245040
# 3                    0.002004           1859.223563
# 4                    0.001995           1859.206841
# ...                       ...                   ...
# 1371063              0.022110           1860.118172
# 1371064              0.022102           1860.146764
# 1371065              0.022082           1860.150877
# 1371066              0.022052           1860.122675
# 1371067              0.022034           1860.095547
#
#          chandrayaan.Moon_MJ2000.RAAN
# 0                            0.000000
# 1                           69.056782
# 2                           69.931678
# 3                           70.800171
# 4                           71.732376
# ...                               ...
# 1371063                     55.172790
# 1371064                     55.172203
# 1371065                     55.171617
# 1371066                     55.171067
# 1371067                     55.170766
#
# [1371068 rows x 5 columns]
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
df.to_csv("690days_MJ2000.csv", index=None)

# %%
df.min()
# Out:
# chandrayaan.Luna.Altitude         37.134621
# chandrayaan.ElapsedDays            0.000000
# chandrayaan.Luna.ECC               0.000167
# chandrayaan.Luna.SMA            1859.110402
# chandrayaan.Moon_MJ2000.RAAN       0.000000
# dtype: float64

# %%
alt_vals= np.array(df["chandrayaan.Luna.Altitude"])
day_vals= np.array(df["chandrayaan.ElapsedDays"])

plt.figure(1, figsize=(14,4), dpi=100)


plt.plot(day_vals, alt_vals)
plt.xlim(0,700)
plt.xlabel("Days Elapsed", fontsize=25)
plt.ylabel("Altitude in km", fontsize= 25)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.grid(True)

# %%
# %matplotlib inline
ecc_vals= np.array(df["chandrayaan.Luna.ECC"])
day_vals= np.array(df["chandrayaan.ElapsedDays"])

fig= plt.figure(2, figsize=(14,4), dpi=100)


plt.plot(day_vals, ecc_vals)
plt.xlabel("Days Elapsed", fontsize=25)
plt.ylabel("Eccentricity", fontsize=25)
plt.xlim(0,700)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.grid(True)

# %%
sma_vals= np.array(df["chandrayaan.Luna.SMA"])
day_vals= np.array(df["chandrayaan.ElapsedDays"])

fig= plt.figure(3, figsize=(14,4), dpi=100)

plt.plot(day_vals, sma_vals)
plt.xlabel("Days Elapsed", fontsize=25)
plt.ylabel("SMA in km", fontsize=25)
plt.xlim(0,700)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.grid(True)

# %%
# %matplotlib inline
raan_vals= np.array(df["chandrayaan.Moon_MJ2000.RAAN"])
day_vals= np.array(df["chandrayaan.ElapsedDays"])

fig= plt.figure(4, figsize=(14,4), dpi=100)

plt.plot(day_vals, raan_vals)
plt.xlabel("Days Elapsed", fontsize=25)
plt.ylabel("RAAN", fontsize=25)
plt.xlim(0,700)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15)
plt.grid(True)

# %%
import matplotlib.image as mpimg

# %%
# %matplotlib inline
img = mpimg.imread('ground track/near equator/4_1.png')
fig= plt.figure(4, figsize=(16,10), dpi=100)
plt.text(20,45, "15 Sep 2019", fontsize=20,        # writing epoch
        bbox={"facecolor": "red", "alpha": 0.3},
        va= "center")

plt.text(600,375, "0 deg", fontsize=15,        # wrinting 0 deg latitude
        bbox={"facecolor": "yellow", "alpha": 0.6},
        va= "center")


plt.text(830,750, "0 deg", fontsize=15,        # wrinting 0 deg
        bbox={"facecolor": "yellow", "alpha": 0.4},
        va= "center")

plt.text(290,750, "-120 deg", fontsize=15,        # wrinting -120 deg
        bbox={"facecolor": "yellow", "alpha": 0.4},
        va= "center")

plt.text(1370,750, "120 deg", fontsize=15,        # wrinting 120 deg
        bbox={"facecolor": "yellow", "alpha": 0.4},
        va= "center")



plt.axis("off")
plt.imshow(img)

# %%
# %matplotlib inline

plt.figure(5, figsize=(14,5))
plt.imshow(img)
print(img.shape)
# Out:
# (814, 1627, 4)
